# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_1='youtube_dataset .csv'

# %%
#read CSV
raw_df = pd.read_csv(file_1)

# %%
raw_df
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1      1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2      1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3      1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4      1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ...                ...                                                ...
# 3939   1553037913-3921  https://socialblade.com/youtube/top/5000/mosts...
# 3940    1553024302-913  https://socialblade.com/youtube/top/5000/mosts...
# 3941   1553034470-3276  https://socialblade.com/youtube/top/5000/mosts...
# 3942   1553040011-4402  https://socialblade.com/youtube/top/5000/mosts...
# 3943   1553027486-1650  https://socialblade.com/youtube/top/5000/mosts...
#
#                       userID  \
# 0                  PewDiePie
# ...

# %%
#sort dataframe based on views
df1=raw_df.sort_values(by='subscribers', axis=0, ascending=False)
df1
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1      1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2      1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3      1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4      1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ...                ...                                                ...
# 3939   1553037913-3921  https://socialblade.com/youtube/top/5000/mosts...
# 3940    1553024302-913  https://socialblade.com/youtube/top/5000/mosts...
# 3941   1553034470-3276  https://socialblade.com/youtube/top/5000/mosts...
# 3942   1553040011-4402  https://socialblade.com/youtube/top/5000/mosts...
# 3943   1553027486-1650  https://socialblade.com/youtube/top/5000/mosts...
#
#                       userID  \
# 0                  PewDiePie
# ...

# %%
#subset the dataframe 
df2=df1.iloc[0:1000, :]
df2
# Out:
#     web-scraper-order                              web-scraper-start-url  \
# 0     1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1     1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2     1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3     1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4     1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ..                ...                                                ...
# 995   1553037784-3900  https://socialblade.com/youtube/top/5000/mosts...
# 996   1553037792-3901  https://socialblade.com/youtube/top/5000/mosts...
# 997   1553037768-3897  https://socialblade.com/youtube/top/5000/mosts...
# 998   1553037724-3888  https://socialblade.com/youtube/top/5000/mosts...
# 999   1553037758-3896  https://socialblade.com/youtube/top/5000/mosts...
#
#              userID                                        userID-href  \
# ...

# %%
#Grouping and perform count over each group
subs_group =  df2.groupby('userID').count()

# %%
subs_group
# Out:
#                   uploads  subscribers  videoviews
# userID
# #Education              0     10334917           0
# #Mind Warehouse       350      5672610  1642709337
# #Refugio Mental       307      8406958  1711273254
# #Refúgio Mental       323      8580557  1309149535
# 1Kilo Oficial         126      5596715  1062790300
# ...                   ...          ...         ...
# whinderssonnunes      362     35123697  2858803818
# wifistudy            9873      7029576   669955562
# zayn                   11      9371581    43661783
# zbing z.             1524      8494739  3236417476
# Área Secreta          784      7991215   981134353
#
# [999 rows x 3 columns]

# %%
#sort dataframe based on views
df2=subs_group.sort_values(by='subscribers', axis=0, ascending=False)
df2
# Out:
#                 uploads  subscribers   videoviews
# userID
# PewDiePie          3779     90210848  20772365682
# T-Series          13218     90194329  65092058996
# Gaming                0     81888222            0
# YouTube Movies        0     77413743            0
# Sports                0     75622870            0
# ...                 ...          ...          ...
# GloZell Green      2316      4719893    845298432
# ETV Jabardasth     3735      4719652   4290216700
# The Timeliners      191      4718880    459254149
# Crafty Panda         84      4712345    890158507
# Troom Troom PT      444      4711742    880150449
#
# [999 rows x 3 columns]

# %%
import csv

# %%
df2.to_csv (r'C:\Users\Pavan\Desktop\Assignments\1202 assignments\Assignment 4\sorted_YT.csv', index = False, header=True)

# %%
dd=df1['channeltype'].value_counts()

# %%
dd
# Out:
# Entertainment    1037
# Music             760
# Games             449
# People            392
# Comedy            275
# Howto             223
# Film              176
# Education         142
# Tech               78
# Sports             56
# News               55
# Autos              14
# Travel             11
# Animals             9
# Nonprofit           3
# Shows               1
# Name: channeltype, dtype: int64

# %%
df1[ctcv]=df1.apply(np.value_count, axis=1)

# %%
df2['channeltype'].value_counts()
# Out:
# Entertainment    284
# Music            240
# Games            115
# Comedy            76
# People            72
# Howto             49
# Film              36
# Education         30
# Tech              19
# Sports            17
# News              17
# Autos              3
# Animals            2
# Nonprofit          1
# Travel             1
# Name: channeltype, dtype: int64

# %%
#rawdata
raw_df
#sort dataframe based on subscribers
df1=raw_df.sort_values(by='subscribers', axis=0, ascending=False)
df1
#subset the dataframe for top 1000 
df2=df1.iloc[0:1000, :]
df2
#channeltype
df2['channeltype'].value_counts()
# Out:
# Entertainment    284
# Music            240
# Games            115
# Comedy            76
# People            72
# Howto             49
# Film              36
# Education         30
# Tech              19
# Sports            17
# News              17
# Autos              3
# Animals            2
# Nonprofit          1
# Travel             1
# Name: channeltype, dtype: int64
